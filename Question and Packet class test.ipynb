# %%
import numpy as np
import pandas as pd
TITLE = 'demo_shw'
import time
import re

# %% [markdown]
# ## Bring in Master Distribution df

# %%
distro_df = pd.read_csv('./MasterDistro.csv') #check to see if this exists perhaps?
distro_df
# Out:
#                      Subcategory  \
# 0              Science - Physics
# 1            Science - Chemistry
# 2              Science - Biology
# 3                Science - Other
# 4          Literature - American
# 5           Literature - British
# 6              Literature - Euro
# 7   Literature - World / Ancient
# 8                 History - Euro
# 9                History - Other
# 10                  History - US
# 11               History - World
# 12        Arts - Classical Music
# 13               Arts - Painting
# 14         Arts - Other Auditory
# 15         Misc - Social Science
# 16               Misc - Myth/Geo
# 17               Misc - Religion
# 18             Misc - Philosophy
# 19       Misc - Trash/CE/OtherAc
#
#                                                  Tags
# 0                                   Science - Physics
# 1                                 Science - Chemistry
# 2                                   Science - Biology
# 3   Science - Astro, Science - CS, Science - Earth...
# 4                               Literature - American
# 5                                Literature - British
# 6                                   Literature - Euro
# 7                        Literature - World / Ancient
# 8                                      History - Euro
# 9                                     History - Other
# 10                                       History - US
# 11                                    History - World
# 12                             Arts - Classical Music
# 13                                    Arts - Painting
# 14         Arts - Other Auditory, Arts - Other Visual
# 15  Social Science - Economics, Social Science - L...
# 16                 Myth - Myth, Geography - Geography
# 17  Religion - Judeo-Christian, Religion - Not Jud...
# 18                            Philosophy - Philosophy
# 19  Current Events - Current Events, Other Academi...

# %% [markdown]
# ## Load CSV from QEMs

# %%
t0 = time.time()
#needs to be all functionalized
count = 0
tu_lines = []
b_lines = []
tu_bool = True
done_bool = False

wp = open("./Demo/demo_shw.csv")
for line in wp:
    if count > 0:
        line = line.replace('Packet','')
    #print(line.split(',')[0])
    if line == '\n':
        print('count:',count,'line',line)
        if tu_bool == False:
            done_bool = True
            break
        else:
            tu_bool = False
    if tu_bool == True and done_bool == False: #in tossups
        tu_lines.append(line)
    elif tu_bool == False and done_bool == False: #in bonuses and not done
        b_lines.append(line)
    count +=1

wp.close()
b_lines.pop(0)
print('lens',len(tu_lines),len(b_lines))
print('time',time.time()-t0)
# Out:
# count: 321 line
#
# count: 645 line
#
# lens 321 323
# time 0.12324094772338867

# %%
print('first',tu_lines[0])
print('last',tu_lines[-1])
# Out:
# first "Tossup Question","Answer","Category","Author","Edited","Packet","Question Number","Comments","Id"
#
# last "A city in what was then this country names a massive mortar commissioned by the Ethiopian emperor Tewodros II. This country briefly established an outpost named for its capital at Sagallo in Djibouti. A coalition of Itelmen, Korak, and Yukaghir mounted an uprising against this country's rule in the 1740s. Constantine Kaufman led an expeditionary force from this country that defeated leaders including Yakub Beg. This country's forces were victorious in a war during which (*) Kuchum was killed, and this country occupied Kokand and Khiva in the late 19th century. This country employed the general Yermak to conquer a state on its Eastern border. This country employed the explorer Vitus Bering to map a region that it would later colonize. For 10 points, name this country that conquered the khanate of Sibir, which is the namesake of its Asian region.","_Russia_n Empire","History - World","Myers","False"," 10","999","Hbunker: just wanted to say I really like this idea||","13863"

# %%
print('first',b_lines[0])
print('last',b_lines[-1])
# Out:
# first "Bonus Leadin","Bonus Part 1","Bonus Answer 1","Bonus Part 2","Bonus Answer 2","Bonus Part 3","Bonus Answer 3","Category","Author","Edited","","Question Number","Comments","Id"
#
# last "Answer the following related to atomic clocks for 10 points each.","This factor for an atomic clock can reach 10\S11\S or higher. This value, which measures how the energy loss due to damping within a resonant element, causes the bandwidth to ~decrease~ for a tuned circuit filter.","_Q_uality _factor_","These devices were used in early atomic clocks and the Hydrogen version of these devices is commonly used as a reference for frequency precision. Another version of these devices, consists of a microwave cavity filled with vapor made of Rubidium and Sulphur and nitrogen gas.","_master_ [accept _Hydrogen maser_ or _Rubidium maser_]","This British scientist was among the first to consider using the properties of atoms for time measurement. He is probably better-known for naming a temperature scale where room temperature is around 300.","Lord _Kelvin_","Science - Physics","Bunker","False"," 13","999","","12300"

# %%
wp_t = open(TITLE + '_t.csv', 'w')
wp_b = open(TITLE + '_b.csv', 'w')

wp_t.write('\n'.join(tu_lines))
wp_b.write('\n'.join(b_lines))

wp_t.close()
wp_b.close()

# %%
t_df = pd.read_csv(TITLE + '_t.csv')
print(t_df.columns)
t_df.head(4)
# Out:
# Index(['Tossup Question', 'Answer', 'Category', 'Author', 'Edited', 'Packet',
#        'Question Number', 'Comments', 'Id'],
#       dtype='object')
#                                      Tossup Question  \
# 0  In one story written in this language, a sheep...
# 1  A character of this type named Adam Link reads...
# 2  In a short story by this author, Pennifeather ...
# 3  A poem by this man warns "No memory of having ...
#
#                                               Answer  \
# 0  _Proto-Indo-European_ [or _PIE_, do not accept...
# 1  _robot_s [or _computer_s, or _AI_, or other ob...
# 2                                  Edgar Allan _Poe_
# 3  Robert _Frost_ \(The first two sentences refer...
#
#                        Category    Author  Edited  Packet  Question Number  \
# 0  Social Science - Linguistics  Thompson    True       1            999.0
# 1         Literature - American  Thompson    True       1            999.0
# 2         Literature - American    Hankin    True      10            999.0
# 3         Literature - American    Hankin    True       8            999.0
#
#   Comments     Id
# 0      NaN  10987
# 1      NaN  11018
# 2      NaN  11025
# 3      NaN  11026

# %%
t_df.sort_values(by = ['Packet']) #remove question number and comments becauset broken
# Out:
#                                        Tossup Question  \
# 0    In one story written in this language, a sheep...
# 113  Peter Burke wrote a book on this movement whic...
# 120  Legendre's formula gives the multiplicity of a...
# 132  Alberto Giacometti ("jacque"-a-metty) strides ...
# 141  This city's bishop was traditionally selected ...
# 160  This author wrote a poem in which a man encoun...
# 162  One painter from this movement depicted her si...
# 92   In Eastern Orthodox tradition, this man's wife...
# 167  Kenneth Wilson developed a method of calculati...
# 199  This author notes that he loves "seventeenth c...
# 202  Combining this compound with 3AQ and HCCA give...
# 217  Vidal and Huron name a "rule" for determining ...
# 221  In a play from this country, the owner of a ca...
# 235  George Washington Cabell (ca-BELL) led the pre...
# 270  ~NOTE TO PLAYER: Two answers required.~ The "t...
# 182  This number is the higher of the two that form...
# 79   In a popular joke, Dean Rusk submitted an expe...
# 159  One person with this surname was an architect ...
# 1    A character of this type named Adam Link reads...
# 17   This goddess decries the unfairness of one peo...
# 187  Near the end of this movie, one character tell...
# 171  One story collection named for this country's ...
# 142  In one story by this author, a farm laborer al...
# 4    This novel notes that "~camaraderie~...superad...
# 292  A 2014 paper in ~The Lancet~ by this scientist...
# 254  The rondo theme of a work in this genre opens ...
# 38   A 2018 paper in ~Science~ showed one of these ...
# 144  In a painting by an artist from this city, an ...
# 54   The first section of this novel references the...
# 245  This river's Csepel (chep-pull) island is a fo...
# ..                                                 ...
# 152  While engaging in a contest of wits with Gagnr...
# 277  This emperor's half-brother and fellow general...
# 200  A "challenge" test using this protein is used ...
# 198  In this novel, the protagonist meets a man who...
# 197  If a coefficient represented by this letter is...
# 83   A rock supposedly imprinted with this person's...
# 190  A 1963 election in one of these places was rig...
# 63   A painting by this artist depicts  black and w...
# 117  In a 2016 article, this scholar said growth in...
# 222  In Ernest Hemingway's short story "The Three-D...
# 21   This composer marketed one set of string quart...
# 207  In complexes with this many d electrons, the s...
# 9    The "double-conquest" theory identifies these ...
# 210  In one work by this painter, two cherubs hold ...
# 121  The narrator of a poem pleads with this figure...
# 50   The problems of received opinion, truth and me...
# 299  The protagonist of this story lies down on the...
# 242  One president during this war may have supplie...
# 108  One film by this director opens with a fifteen...
# 107  One of these events in 1967 was prophecied by ...
# 246  In 2018, this state's legislature passed a res...
# 102  The protagonist of one of this author's novels...
# 260  Led by Feryal Ozel, the Xtreme Astrophysics Gr...
# 261  One ruler of this dynasty retained a group of ...
# 43   One version of this technique is analyzed usin...
# 88   In the introudction of this work, its authors ...
# 86   A saint with this name had a dream in which he...
# 267  In one novel, the narrator reflects how one of...
# 230  One imaging technique that uses the induced ve...
# 30   In one card game, playing an Alchemist lets yo...
#
#                                                 Answer  \
# 0    _Proto-Indo-European_ [or _PIE_, do not accept...
# 113                                   _Annales_ School
# 120  _factorial_ [grudgingly accept _exclamation po...
# 132                            Henri _Cartier-Bresson_
# 141          Veliky _Novgorod_ [accept _Old Novgorod_]
# 160                                     Dylan _Thomas_
# 162                                    _Impressionism_
# 92                                    Pontius _Pilate_
# 167  _gluon_s [accept __Glueballs__ before "balls" ...
# 199  Jorge Luis _Borges_ \(lead-in is from "Borges ...
# 202  _glycerol_ [or _glycerin_; or _1,2,3-Propanetr...
# 217  _mixing_ [or _stirring_; accept __impelling__ ...
# 221                                            _Italy_
# 235                                      _Embargo_ Act
# 270  _China_ and _Japan_ [accept _Tang_ Dynasty, _M...
# 182                                              _Six_
# 79   _F_rancois _Duvalier_ [accept _Papa Doc_; prom...
# 159  _Bernoulli_ [accept any of _Elisabeth Bernoull...
# 1    _robot_s [or _computer_s, or _AI_, or other ob...
# 17   _Juno_ [prompt with "Give the Roman equivalent...
# 187                            ~_Burn After Reading_~
# 171               the _Netherlands_ [accept _Holland_]
# 142                            Katherine Anne _Porter_
# 4                       _~Far From the Madding Crowd~_
# 292                                     James _Watson_
# 254             _violin sonata_ [prompt on __sonata__]
# 38   _Darwin's finch_es [or _Galapagos finch_es; or...
# 144   _Venice_ [accept _Venetian_ school or _Venezia_]
# 54   ~_Dream of the Red Chamber_~ [or ~_The Story o...
# 245  _Danube_ [or _Donau_, or _Dunaj_, or _Duna_, o...
# ..                                                 ...
# 152                                _Njörð_r (Nuh-yord)
# 277                              _Julian_ the Apostate
# 200  _albumin_ [or human serum _albumin_, or bovine...
# 198                        _~Candide_ ou, l'Optimisme~
# 197                                            _alpha_
# 83                      _Lut_ ibn Haran [accept _Lot_]
# 190  _bantustans_ [prompt on "__homelands__ before ...
# 63                                         Paul _Klee_
# 117                                  Joseph _Stiglitz_
# 222  _Walpole_ [accept Hugh _Walpole _or Horace _Wa...
# 21                         Franz Joseph "Papa" _Haydn_
# 207                                             _five_
# 9    _Magyar_s [or _magyarok_; accept _Hungarian_s ...
# 210                                Peter Paul _Rubens_
# 121                                            _Venus_
# 50                                     Jacques _Lacan_
# 299                                          "_Bliss_"
# 242  _Sri Lankan Civil War_ [accept _First Eelam Wa...
# 108                                    Robert _Altman_
# 107  _solar eclipse_ [prompt on __eclipse__; do not...
# 246                                          _Georgia_
# 102                                     Jack _Kerouac_
# 260  _neutron_ Star [anti-prompt on __pulsar__; acc...
# 261  _Safavid_ Dynasty [prompt on __Persia__; accep...
# 43   gel _electrophoresis_ [or polyacrylamide gel _...
# 88         _Fear and Trembling_ [or _Frygt og Baeven_]
# 86   _John_ [accept specific saints including _John...
# 267                                       _guillotine_
# 230  _Polarization_ [accept word forms like _Polari...
# 30   _draw_ing a card [accept drawing any arbitrary...
#
#                                   Category     Author  Edited  Packet  \
# 0             Social Science - Linguistics   Thompson    True       1
# 113                Philosophy - Philosophy     Bunker    True       1
# 120                         Science - Math   Thompson    True       1
# 132                    Arts - Other Visual    Suttell   False       1
# 141                         History - Euro      Myers   False       1
# 160                   Literature - British    Suttell   False       1
# 162                        Arts - Painting    Suttell    True       1
# 92              Religion - Judeo-Christian     Hijazi    True       1
# 167                      Science - Physics    Kruskie    True       1
# 199           Literature - World / Ancient    Suttell    True       1
# 202                      Science - Biology  Mukherjee    True       1
# 217                    Science - Chemistry  Mukherjee    True       1
# 221                      Literature - Euro    Suttell   False       1
# 235                           History - US      Myers   False       1
# 270                        History - World      Myers   False       1
# 182                 Arts - Classical Music         Su   False       1
# 79                         History - World      Myers   False       1
# 159        Other Academic - Other Academic     Bunker   False       1
# 1                    Literature - American   Thompson    True       1
# 17                             Myth - Myth     Hankin   False       1
# 187                      Trash - Movies/TV     Bunker   False       2
# 171                      Literature - Euro      Myers    True       2
# 142                  Literature - American      Myers    True       2
# 4                     Literature - British     Hankin    True       2
# 292                        Science - Other   Thompson    True       2
# 254                 Arts - Classical Music     Bubolz   False       2
# 38                       Science - Biology     Magin     True       2
# 144                        Arts - Painting    Suttell    True       2
# 54            Literature - World / Ancient     Bunker    True       2
# 245                  Geography - Geography   Thompson   False       2
# ..                                     ...        ...     ...     ...
# 152                            Myth - Myth     Bubolz   False      15
# 277                        History - Other      Myers   False      15
# 200                      Science - Biology  Mukherjee    True      15
# 198                      Literature - Euro      Myers    True      15
# 197                        Science - Other     Magin     True      15
# 83          Religion - Not Judeo-Christian     Hijazi    True      15
# 190                        History - World      Myers   False      15
# 63                         Arts - Painting     Bunker    True      15
# 117             Social Science - Economics     Bunker    True      15
# 222                   Literature - British     Hijazi   False      15
# 21                  Arts - Classical Music     Hankin   False      16
# 207                    Science - Chemistry  Mukherjee    True      16
# 9                           History - Euro     Hankin   False      16
# 210                        Arts - Painting    Suttell    True      16
# 121                   Literature - British     Hijazi   False      16
# 50   Social Science - Psychology/Sociology     Bunker   False      16
# 299           Literature - World / Ancient    Suttell   False      16
# 242                        History - World      Myers   False      16
# 108                    Arts - Other Visual    Suttell   False      16
# 107                           History - US      Myers   False      16
# 246                  Geography - Geography   Thompson   False      16
# 102                  Literature - American     Hijazi    True      16
# 260                        Science - Astro     Bunker   False      16
# 261                        History - World      Myers   False      16
# 43                       Science - Biology     Magin     True      16
# 88                 Philosophy - Philosophy     Bunker    True      16
# 86              Religion - Judeo-Christian     Hijazi    True      16
# 267                      Literature - Euro     Hijazi   False      16
# 230                      Science - Physics     Bunker   False      16
# 30                           Trash - Other   Thompson   False      16
#
#      Question Number                                           Comments     Id
# 0              999.0                                                NaN  10987
# 113            999.0                                                NaN  12360
# 120            999.0       Hbunker: Maybe mention the Gamma function?||  12406
# 132            999.0                                                NaN  12565
# 141            999.0                                                NaN  12617
# 160            999.0                                                NaN  12718
# 162            999.0                                                NaN  12721
# 92             999.0  nour_hijazi: I'm iffy about the archaeology cl...  11774
# 167            999.0  Hbunker: Add a clue about quark gluon plasma||...  12735
# 199            999.0                                                NaN  12826
# 202            999.0                                                NaN  12846
# 217            999.0                                                NaN  12878
# 221            999.0  Hbunker: Justin French: multatuli's pseudonym ...  12888
# 235            999.0                                                NaN  13153
# 270            999.0  Hbunker: This was a buzzer race at wokou pirat...  13309
# 182            999.0  CPiGuy: according to Michael the last C-sharp ...  12758
# 79             999.0                                                NaN  11568
# 159            999.0  Hbunker: consider deleting reference to Elizab...  12715
# 1              999.0                                                NaN  11018
# 17             999.0                                                NaN  11043
# 187              NaN                                                NaN  12787
# 171            999.0                                                NaN  12739
# 142            999.0  nour_hijazi: I feel like including The Jilting...  12627
# 4              999.0                                                NaN  11027
# 292            999.0  Hbunker: this seems fine to me although I'd co...  13785
# 254            999.0  CPiGuy: first clue maybe too transparent?||joe...  13271
# 38             999.0  Hbunker: Not a fan of just like dropping the y...  11170
# 144            999.0  esuttell: Move back St Mark church clue||esutt...  12648
# 54             999.0  Hbunker: May add some more translations in ans...  11291
# 245            999.0             CPiGuy: investigate for transparency||  13221
# ..               ...                                                ...    ...
# 152            999.0  Hbunker: change sentences that are about peopl...  12695
# 277            999.0                                                NaN  13324
# 200            999.0                                                NaN  12844
# 198            999.0                                                NaN  12825
# 197            999.0   Hbunker: Move particle physics from first line||  12823
# 83             999.0                                                NaN  11592
# 190            999.0                         Hbunker: added powermark||  12790
# 63             999.0  esuttell: Deleted Guggenheim clue because that...  11308
# 117            999.0  Hbunker: Potentially change lead-in or make it...  12372
# 222            999.0                                                NaN  12889
# 21             999.0                                                NaN  11047
# 207            999.0                                                NaN  12852
# 9              999.0                                                NaN  11034
# 210            999.0                                                NaN  12859
# 121            999.0  nour_hijazi: I'll edit this more to talk more ...  12494
# 50             999.0                                                NaN  11273
# 299            999.0                                                NaN  13804
# 242            999.0  Hbunker: Yo Jakob. Please use "[]" for alterna...  13195
# 108            999.0                                                NaN  12117
# 107            999.0  Hbunker: Just a note: we are using a consisten...  12110
# 246            999.0  Hbunker: Maybe because I watched a Lets Play o...  13223
# 102            999.0  jsmyers: This seems to skew a bit hard; I'd ad...  12006
# 260            999.0  Hbunker: Consider moving power to be before so...  13298
# 261            999.0                                                NaN  13299
# 43             999.0  emukherj: Original version: Results from this ...  11175
# 88             999.0  Hbunker: Heavy WIP. http://sorenkierkegaard.or...  11641
# 86             999.0                                                NaN  11637
# 267            999.0  Hbunker: Players said this tossup was very har...  13306
# 230            999.0  touchpack: 1) Polarized sunglasses are easier ...  12906
# 30             999.0                                                NaN  11097
#
# [320 rows x 9 columns]

# %%
b_df = pd.read_csv(TITLE + '_b.csv')
b_df = b_df.fillna(0)
print(b_df.columns)
b_df = b_df.rename(columns = {'Unnamed: 10': 'Packet'})
b_df = b_df.astype({'Packet':'int32'}, errors = 'ignore')
b_df.head(10) #Unnamed: 10 is packet
# Out:
# Index(['Bonus Leadin', 'Bonus Part 1', 'Bonus Answer 1', 'Bonus Part 2',
#        'Bonus Answer 2', 'Bonus Part 3', 'Bonus Answer 3', 'Category',
#        'Author', 'Edited', 'Unnamed: 10', 'Question Number', 'Comments', 'Id'],
#       dtype='object')
#                                         Bonus Leadin  \
# 0  Answer the following about generally discredit...
# 1  This event's perpetrator was angered by the ma...
# 2  The protagonist of this novella works in a lib...
# 3  This character does not get to finish telling ...
# 4  Debate over this legislation hinged on certain...
# 5  In this speech, the title question was answere...
# 6  This man led his umbrella labor organization i...
# 7  For 10 points each, give the following about e...
# 8  He got one of his noble titles by marrying Ann...
# 9  For 10 points each, give the following about t...
#
#                                         Bonus Part 1  \
# 0  Edmund Halley proposed that the Earth consiste...
# 1  Identify this event in which Dan White, a rece...
# 2  Name this novella, titled for a song sung at a...
# 3  Name this character, who then gives a long and...
# 4  Name this first bill ever introduced in the U....
# 5  Name this speech, which declared "your shout o...
# 6  Name this man, who led the CIO into its merger...
# 7  This American general, who later commanded U.N...
# 8  Name this man, who left his captaincy of Calai...
# 9  It was a hearing for this leader of the Protes...
#
#                                       Bonus Answer 1  \
# 0  _aurora_ borealis [or _aurora_ australis, or _...
# 1  the _assassination_ of George _Moscone_ and Ha...
# 2                              _~Goodbye, Columbus~_
# 3  _Geoffrey_ _Chaucer_ [accept either name; prom...
# 4  _Judiciary Act_ of _1789_ [or ~An _Act to Esta...
# 5  "_What, to the slave, is the Fourth of July?_"...
# 6                            Walter Philip _Reuther_
# 7                                Douglas _MacArthur_
# 8  Richard _Neville_, 16th earl of _Warwick_ [acc...
# 9                                    Martin _Luther_
#
#                                         Bonus Part 2  \
# 0  A briefly popular theory claimed that the Moon...
# 1  Following the shooting, Milk's body was discov...
# 2  ~Goodbye, Columbus~ is by this Jewish-American...
# 3  The character Chaucer serves as the frame narr...
# 4  Part of the Judiciary Act of 1789 was ruled un...
# 5  "What, to the slave, is the Fourth of July?" w...
# 6  Reuther led the UAW in the "Battle of the Over...
# 7  The U.S. field army of this number was the fir...
# 8  Neville "the Kingmaker" fought for both sides ...
# 9  The excommunicated Luther got to have a hearin...
#
#                                       Bonus Answer 2  \
# 0                     _moonquake_s [or just _quake_s
# 1                                 Dianne _Feinstein_
# 2                               Philip Milton _Roth_
# 3  ~The _Canterbury Tales_~ [or _~Tales of Canter...
# 4                             ~_Marbury_ v. Madison~
# 5  Frederick _Douglass_ [or Frederick Augustus Wa...
# 6         Henry _Ford_ [accept _Ford Motor_ Company]
# 7                        United States _Eight_h Army
# 8                                            _rose_s
# 9  _Frederick_ III [or _Friedrich_ III; accept _F...
#
#                                         Bonus Part 3  \
# 0  This moon's unusual orbital parameters led Shk...
# 1  The assassinations of Moscone and Milk took pl...
# 2  In "You Can't Tell a Man by the Song He Sings,...
# 3  Chaucer the character isn't just a bad rhymer:...
# 4  Ironically, it was Marshall who had failed to ...
# 5  During the Civil War, two of Douglass's sons s...
# 6  As Reuther's relationship with Meany worsened,...
# 7  The Eighth Army set about defending a "perimet...
# 8  Less than a month after Neville's death, the L...
# 9  The "judge" at the Diet of Worms was the archb...
#
#                                       Bonus Answer 3               Category  \
# 0                                           _Phobos_        Science - Astro
# 1                                    _San Francisco_           History - US
# 2  _Communist_ Party of the United States of Amer...  Literature - American
# 3  "My _wit is short_, ye may wel understonde" [a...   Literature - British
# 4                               secretary of _state_           History - US
# 5  _54th Massachusetts_ \(Volunteer Infantry\) Re...           History - US
# 6  _Teamster_s union [accept _International Broth...           History - US
# 7     _Pusan_ [or _Busan_; accept _Pusan Perimeter_]           History - US
# 8                             Battle of _Tewkesbury_         History - Euro
# 9  _Johann_ _Eck_ [accept either; accept _John_; ...         History - Euro
#
#      Author  Edited  Packet  Question Number  \
# 0  Thompson    True       1            999.0
# 1  Thompson   False      12            999.0
# 2    Hankin   False       5            999.0
# 3    Hankin   False       5            999.0
# 4    Hankin   False      13            999.0
# 5    Hankin   False       5            999.0
# 6    Hankin   False       4            999.0
# 7    Hankin   False       8            999.0
# 8    Hankin   False       2            999.0
# 9    Hankin   False      16            999.0
#
#                                             Comments    Id
# 0  Hbunker: Don't know much about astro, but how ...  9578
# 1    Hbunker: change second part to something else||  9586
# 2                                                  0  9588
# 3                                                  0  9589
# 4                                                  0  9590
# 5      CPiGuy: jakob: this bonus needs a hard part||  9591
# 6  Hbunker: This seems rather easy to me but it's...  9593
# 7                                                  0  9594
# 8  CPiGuy: jakob says: ease up on the hard part||...  9595
# 9                                                  0  9596

# %%
b_df.sort_values(by = ['Packet'])
# Out:
#                                           Bonus Leadin  \
# 304  For 10 points each, give the following about P...
# 0    Answer the following about generally discredit...
# 200  Answer the following about the early history o...
# 201  Answer the following about agriculture in 18th...
# 217  This musical piece begins with the left hand p...
# 221  This quantity, which ranges from 0 to 2 pi, ar...
# 226  Answer the following about Australia's foreign...
# 165  This geometry occurs in carbons with sp3 hybri...
# 229  This candidate defeated Bob Marshall, who refe...
# 241  Answer the following about the geography of No...
# 148  Nicholas Hilliard frequently painted miniature...
# 146  These cells are selectively destroyed by anti-...
# 31   This character sings the words "Notte e giorno...
# 41   This religious group promotes the traditional ...
# 131  This belief was espoused by Jacques Monod in h...
# 282  This woman commissioned building projects incl...
# 46   This object "bathed in your languor of waves"....
# 283  Aldhelm was inspired by Symphosius to write so...
# 71   For 10 points each, name some modern Levantine...
# 255  A member of the Sieppe family in this novel ma...
# 170  The totality of these relations can be represe...
# 137  Answer the following about cattle being killed...
# 126  Thomas Carlyle and Frederick Maurice watch lab...
# 118  Salvador Dalí claimed that these artworks were...
# 161  This concept is said to "bury the day" with th...
# 105  Answer some questions about French plays with ...
# 101  Manuel DeLanda wrote a book titled ~Philosophy...
# 99   This model of endogenous growth includes a  te...
# 98   Answer the following about references to Alexa...
# 166  Like succimer, this compound can be used to tr...
# ..                                                 ...
# 260  Answer the following about Oberlin College's c...
# 120  It's time to go to the opera! For 10 points ea...
# 122  Answer the following about the conquest of Nor...
# 228  Over the past several years, China has drastic...
# 208  The Fürst-Plattner rule describes the stereo-s...
# 129  The title concept of this book is called "the ...
# 135  An incident in this city involved Paul rebukin...
# 273  Answer the following about structures from abs...
# 104  Answer the following about the Watts riots and...
# 249  Answer some questions about the influences of ...
# 253  This religious group is commonly referred to b...
# 47   Some small cell lung cancers can secrete this ...
# 18   You are a music lover in medieval Europe. Give...
# 169  This artist was imprisoned in Martinique with ...
# 291  A group led by Queen Yagowania, the Erie peopl...
# 287  Answer the following about the development of ...
# 44   Some of the assumptions of this model include ...
# 50   This law relates the magnetic field to its cur...
# 263  Measuring the release of the radioactive 51 is...
# 298  One of the key depictions of this deity was th...
# 266  Answer some questions about British adaptation...
# 202  Answer the following about historiography in t...
# 94   In an obvious allusion to A.J. Ayer, this non-...
# 83   Swimming is a pervasive motif in the poetry of...
# 66   Answer some questions related to frogs in anci...
# 93   Identify the following academics associated wi...
# 84   Answer some questions about the appearance of ...
# 89   Answer some questions about important countere...
# 9    For 10 points each, give the following about t...
# 140  Answer the folllowing about homosexuality in m...
#
#                                           Bonus Part 1  \
# 304                                                  0
# 0    Edmund Halley proposed that the Earth consiste...
# 200  Much of South Carolina's early gentry originat...
# 201  Traditions of communal village property owners...
# 217  Name this G-sharp minor piece whose melody beg...
# 221  Name this "phase" that describes the global ph...
# 226  This Australian Prime Minister lost public sup...
# 165  Name this type of molecular geometry that has ...
# 229  Name this first transgender US State legislato...
# 241  This huge network of canyons is the home of th...
# 148  Name this English monarch who is the subject o...
# 146  Name these cells found between the molecular a...
# 31   Name this character. Near the end of the opera...
# 41   Identify this religious tradition that centers...
# 131  Name this philosophical position that was adva...
# 282  Name this woman who served as de facto chief a...
# 46   Name this object, the subject of a poem in whi...
# 283  Identify these works, including one name "Crea...
# 71   This Lebanese Christian poet created the chara...
# 255  Name this novel about the title dentist who mu...
# 170  Name these information-carrying units between ...
# 137  This leader ordered all of his realm's milk co...
# 126  Name this painting by Ford Maddox Brown that d...
# 118  Identify these Viollet-le-Duc-inspired public ...
# 161  Identify this concept that is declared to be  ...
# 105  Laurence Olivier was in the original cast of t...
# 101  Identify this philosophical ideas that says re...
# 99   Identify this model of economic growth that wa...
# 98   This Malian epic refers to Alexander as "the m...
# 166  Name this hexadentate ligand, most often used ...
# ..                                                 ...
# 260  This screenwriter, who graduated from Oberlin ...
# 120  This city's opera house took Ove Arup's engine...
# 122  These native inhabitants of Japan were displac...
# 228  This system that penalizes citizens for "irres...
# 208  Identify this compound that can be formed from...
# 129  Identify this 1762 Rousseau book that opens "m...
# 135  Identify this city where Paul started his evan...
# 273  This non commutative group of eights elements,...
# 104  This governor of California during the riots w...
# 249  Plautus' play ~Menaechmi~ inspired this Shakes...
# 253  Identify this religious group founded by A. C....
# 47   Name this hormone secreted by the posterior pi...
# 18   If you attend Church services, you can hear th...
# 169  Name this Cuban painter of ~El Tercer Mundo~ w...
# 291  Name this series of wars of expansion that a N...
# 287  The use of troupes of blackfaced minstrels was...
# 44   Name this model of option pricing that calcula...
# 50   Name this law from electromagnetism that says ...
# 263  Name this transition metal which produces stai...
# 298  Name this daughter of Tefnut and Shu, and moth...
# 266  This author is best known for her portrayal of...
# 202  This historian of ~France and England in North...
# 94   Name this concept that is paired with ~Refutat...
# 83   What's likely the most famous appearance of sw...
# 66   Homer was originally thought to be the author ...
# 93   This current Chicago scholar wrote about how G...
# 84   Lord Darnley is dubbed Arrigo in ~Maria Stuard...
# 89   The Weierstrass functions are a family of func...
# 9    It was a hearing for this leader of the Protes...
# 140  In this memoir, a Mughal emperor discussed his...
#
#                                         Bonus Answer 1  \
# 304  George _Gershwin_ [or Jacob _Gershwine_ or Jac...
# 0    _aurora_ borealis [or _aurora_ australis, or _...
# 200                                         _Barbados_
# 201                               _enclosure_ movement
# 217                                    _La campanella_
# 221   _Berry_ phase [also accept _Pancharatnam_ phase]
# 226                                      Harold _Holt_
# 165                                     _tetrahedral_
# 229                                      Danica _Roem_
# 241          _Copper_ Canyon [accept Canon de _Cobre_]
# 148      Queen _Elizabeth I_ [Prompt on __Elizabeth__]
# 146                          _Purkinje_ cell or neuron
# 31                                        _Leporello_
# 41                      _Falun Gong_ [or _Falun Dafa_]
# 131  _indeterminism_ [accept _metaphysical libertar...
# 282  _Hurrem_ Sultan [accept _Roxelana_, Alexandra ...
# 46   The _Drunken Boat_ [or _Le Bateau ivre_; accep...
# 283                             Anglo-Saxon _riddle_s
# 71     Khalil _Gibran_ [accept Gibran Khalil _Gibran_]
# 255  _McTeague_: A Story of San Francisco [Do not r...
# 170  Interpersonal _Ties_ [accept _Weak Ties_ or _S...
# 137                                       _Shaka_ Zulu
# 126                                           _~Work~_
# 118  _Entrances_ to the _Paris Metro_ [accept _Mét...
# 161                                             _time_
# 105                           Jean _Anouilh_ (AWN-WEE)
# 101  _simulation_ [accept obvious equivalents like ...
# 99          _Lucas_ model [accept _Lucas-Uzawa_ model]
# 98          The Epic of _Sundiata_ [accept _Son-Jara_]
# 166  _EDTA_ [or _ethylenediaminetetraacetic acid_ o...
# ..                                                 ...
# 260                                        Mark _Boal_
# 120                                           _Sydney_
# 122                                             _Ainu_
# 228     _social credit_ [accept _shèhuì xìnyòng_ tǐxì]
# 208  _cyclohexene_ [ask them to spell it if you hav...
# 129  ~On the _Social Contract_; or, Principles of P...
# 135                           _Antioch_ on the Orontes
# 273                                      _Quaternions_
# 104           _P_at _Brown_ [prompt on just __Brown__]
# 249                           ~_The Comedy of Errors_~
# 253  _ISKCON_ [or the _International Society for Kr...
# 47   arginine _vasopressin_ [or _antidiuretic hormo...
# 18   _Gregory_ [or _Gregorius_; accept _Gregorian_ ...
# 169                                      Wifredo _Lam_
# 291                                      _Beaver_ Wars
# 287                                       Dan _Emmett_
# 44                        _Black-Scholes_-Merton model
# 50                                   _Biot-Savart_ Law
# 263                               _chromium_ [or _Cr_]
# 298                                     _Nut_ ("noot")
# 266                                 Charlotte _Lennox_
# 202                                  Francis _Parkman_
# 94         _Proof_s [accept ~_Proofs and Refutation~_]
# 83                                  "_Song of Myself_"
# 66                                              _mice_
# 93                                Martha C. _Nussbaum_
# 84                           Vittorio Amedeo _Alfieri_
# 89   _differentiability_ [or word forms such as _di...
# 9                                      Martin _Luther_
# 140                                      _~Baburnama~_
#
#                                           Bonus Part 2  \
# 304                                                  0
# 0    A briefly popular theory claimed that the Moon...
# 200  This 1715 war cleared much of South Carolina o...
# 201  This agriculturist and author criticized the e...
# 217  "La campanella" is an Etude by this composer a...
# 221  The Berry phase can be observed in the Aharono...
# 226  Australia was a founding member of this intern...
# 165  Like octahedral complexes, tetrahedral ones ca...
# 229  ~Note: Description Acceptable~ In the same ele...
# 241  Copper Canyon is located in this largest Mexic...
# 148  Hilliard, as well as his successor Isaac Olive...
# 146  Purkinje cells release this inhibitory neurotr...
# 31   Leporello is the servant of this title charact...
# 41   This nation has called Falun Gong a "heretical...
# 131  The idea of indeterminism is related to the ph...
# 282  Hurrem likely had this Grand Vizier nicknamed ...
# 46   This Symbolist poet penned "The Drunken Boat" ...
# 283  This resident of Whitby Abbey was inspired by ...
# 71   This poet, whose name translates as "my people...
# 255  Frank Norris's ~McTeague~ takes place in this ...
# 170  Ties are central to the study to these entitie...
# 137  A massive epizootic of this cattle disease cau...
# 126  Brown's painting ~The Last of England~ is this...
# 118  The entrances to the Paris Metro are in this a...
# 161  "Burnt Norton" and the ~Four Quartets~ were wr...
# 105  This contemporary of Moliere and Corneille dre...
# 101  This contemporary Swedish  philosopher provide...
# 99   In this perhaps more famous model of economic ...
# 98   In this story, Daniel Dravot is revered as a s...
# 166  EDTA is commonly used alongside Fast Sulphon B...
# ..                                                 ...
# 260  This Oberlin grad described her father Bruce's...
# 120  This architect's design for the Guangzhou Oper...
# 122  Northern Honshu was conquered from this tribe ...
# 228  This Northwestern region of China populated by...
# 208  Cyclohexene is most stable in the half type of...
# 129  In his ~Discourse on the Origins of Inequality...
# 135  Peter is held to be the first bishop of Antioc...
# 273  The SU\(2\) group is the symmetry associated w...
# 104  After the riots, this African-American former ...
# 249  Glycerium represents the title character of th...
# 253  Followers of ISKCON frequently distribute a tr...
# 47   Vasopressin is produced in this part of the br...
# 18   Perhaps you're a fan of this woman, whose poem...
# 169  Lam's work often was inspired by African masks...
# 291  This confederacy, which at the time included t...
# 287  This composer of anti-slavery songs such as "W...
# 44   This Lebanese-American statistician maintains ...
# 50   When magnetostatics do not apply, Biot-Savart ...
# 263  Chromium trioxide dissolved in sulfuric acid s...
# 298  Egyptian deities are often depicted with the h...
# 266  This author noted that his novel ~Joseph Andre...
# 202  Frederick Jackson Turner's magnum opus was tit...
# 94   Lakatos collaborated with this Austrian-born p...
# 83   In "I Sing the Body Electric", the speaker lis...
# 66   Frogs also provides a chorus for Dionysus and ...
# 93   The founder of the so-called Chicago School of...
# 84   Mortimer kills himself after his plan to rescu...
# 89   The converse of the intermediate value theorem...
# 9    The excommunicated Luther got to have a hearin...
# 140  The Hindu slave Khusrau Khan briefly took this...
#
#                                         Bonus Answer 2  \
# 304                                                  0
# 0                       _moonquake_s [or just _quake_s
# 200                                      _Yamasee_ War
# 201                                     Arthur _Young_
# 217                                      Franz _Liszt_
# 221                                   _Magnetic_ Field
# 226  _S_outh_e_ast _A_sian _T_reaty _O_rganization ...
# 165               _Jahn-Teller_ (YAN TELL-her) effect
# 229  _drawing lots_ [accept similar answers such as...
# 241                                        _Chihuahua_
# 148                              Portrait _miniatures_
# 146              _GABA_ [or _gamma-amniobutyric acid_]
# 31                                     _Don Giovanni_
# 41                        People's Republic of _China_
# 131                   _free will_ [prompt on __will__]
# 282  _Ibrahim_ of Parga [accept _Ibrahim_ Pasha, _I...
# 46                        Arthur _Rimbaud_ (Ram-"bow")
# 283                                          _Caedmon_
# 71   Yehuda _Amichai_ [accept his original German n...
# 255                                    _San Francisco_
# 170                                  _social networks_
# 137                                       _rinderpest_
# 126                                            _Tondo_
# 118                                      _Art Nouveau_
# 161                             Thomas Stearns _Eliot_
# 105                             Jean-Baptiste _Racine_
# 101                                  Nicklas _Bostrom_
# 99                                  _Solow_ Swan model
# 98   "_The Man who Would Be King_" [by Rudyard Kipl...
# 166                                       _titration_
# ..                                                 ...
# 260                                   Alison _Bechdel_
# 120                                       Zaha _Hadid_
# 122                                           _Emishi_
# 228                                         _Xinjiang_
# 208                               _chair_ conformation
# 129                                     _Noble Savage_
# 135  _Maronite_ Catholic Church [accept Syriac _Mar...
# 273                               _Weak_ Nuclear Force
# 104                                      Tom _Bradley_
# 249       ~_Andria_~ [accept ~_The Girl from Andros_~]
# 253                                the _Bhagavad Gita_
# 47                                      _hypothalamus_
# 18   Saint _Hildegard_ of Bingen [or _Hildegard von...
# 169                      ~Les _Demoiselles d'Avignon_~
# 291  _Iroquois_ League [accept _Hotinoshonni_ or _H...
# 287                           Stephen Collins _Foster_
# 44                             Nassim Nicholas _Taleb_
# 50                             _Jefimenko_'s equations
# 263                                  _Jones_ oxidation
# 298  _cows_ [prompt on __cattle__; do not accept or...
# 266                                   Henry _Fielding_
# 202                                     the _frontier_
# 94                              Paul Karl _Feyerabend_
# 83                                           _fireman_
# 66                                     _Aristophanes_
# 93                               Ronald Salmon _Crane_
# 84   Friedrich _Schiller_ [or Johann Christoph Frie...
# 89   _13_ [The function is the _Conway base 13 func...
# 9    _Frederick_ III [or _Friedrich_ III; accept _F...
# 140                                _Sultan_ of _Delhi_
#
#                                           Bonus Part 3  \
# 304                                                  0
# 0    This moon's unusual orbital parameters led Shk...
# 200  South Carolina was named for this English mona...
# 201  This process further weakened English village ...
# 217  Liszt's "La campanella", and five other etudes...
# 221  Pancharatnam (Pan-car-rat-nam) observed the ge...
# 226  Australia held this modern-day country as a co...
# 165  In the absence of Jahn-Teller distortion, the ...
# 229  The elections between Marshall and Roem and Si...
# 241  Copper Canyon is part of this mountain range t...
# 148  In the Ditchley portrait, Elizabeth stands on ...
# 146  GABA-A receptors are ligand-gated channels for...
# 31   During the feast scene, Leporello is annoyed b...
# 41   This Sunni Chinese ethnic group, which is not ...
# 131  A contemporary philosopher with this surname a...
# 282  Hurrem and Ibrahim were both powerful at the c...
# 46   This collection by Rimbaud, published after ~A...
# 283  Numerous works of Old English literature are c...
# 71   A commentary on the destruction of the Six-Day...
# 255  Brave Orchid meets her sister Moon Orchid at t...
# 170  This contemporary French philosopher wrote abo...
# 137  This second-largest ethnic group in South Afri...
# 126  Brown was associated with this British art mov...
# 118  This Catalan architect was a major proponent o...
# 161  In this man's poem "Meeting Point," the speake...
# 105  A notable difference between Euripides' ~Hippo...
# 101  This other philosopher wrote about simulacrum ...
# 99   The classical Solow model does not account for...
# 98   In the ~Shahnameh~, Alexander is confronted wi...
# 166  A common solution used to store nucleic acids ...
# ..                                                 ...
# 260  Oberlin is home to a society dedicated to this...
# 120  Lyon's opera house was designed by this French...
# 122  The Matsumae, a clique of samurai, established...
# 228  This internal passport and household registrat...
# 208  Ring flipping in cyclohexane moves substituent...
# 129  This feminist author's 1988 book ~The Sexual C...
# 135  The successor to Peter as bishop of Antioch is...
# 273  This number is the dimension of a representati...
# 104  Brown's response to the Watts riots was percei...
# 249  Plautus use of stock characters heavily influe...
# 253  Swami Prabhupada designed an ornate palace in ...
# 47   The central form of this condition results fro...
# 18   If you're growing up in the 1300s, your elders...
# 169  Picasso depicted this type of person multiple ...
# 291  This sixth member tribe of the Iroquois league...
# 287  Emmett and Foster's works were also frequently...
# 44   This lemma is used to determine the derivative...
# 50   This doubly eponymous potential also incorpora...
# 263  This catalyst contains chromium oxide supporte...
# 298  Ra was afraid of challengers to his throne, so...
# 266  Timothy Crabshaw is reminiscent of Sancho Panz...
# 202  Mercy Otis Warren, the daughter of James Otis,...
# 94   Lakatos was born in this European country: the...
# 83   In this other poem, the speaker asks the "ruff...
# 66   In one of Aesop's fables, frogs who desire a k...
# 93   Earlier, this "mother of social work" taught a...
# 84   The lovesick speaker "tried shooting myself, b...
# 89   A non-constant and infinitely continuously dif...
# 9    The "judge" at the Diet of Worms was the archb...
# 140  This "father of Urdu literature" had an ambigu...
#
#                                         Bonus Answer 3  \
# 304                                                  0
# 0                                             _Phobos_
# 200                                       _Charles II_
# 201                            _Industrial Revolution_
# 217                                 Niccolo _Paganini_
# 221                                  _optical pumping_
# 226                             _P_apua _N_ew _G_uinea
# 165  _e\sg\s_ and _t\s2g\s_ ["_e-sub-g_" and "_t-su...
# 229                         Commonwealth of _Virginia_
# 241                                     _Sierra Madre_
# 148  _Globe_ [accept _map_ of England, as that is w...
# 146  _chloride_ [or _Cl-minus_; do NOT accept "chor...
# 31                                           _Figaro_
# 41                                  _Hui_ [or _Huizu_]
# 131  _Strawson_ [accept _Galen Strawson_ or _P.F. S...
# 282  _Suleiman_ _I_ _The Magnificent_ [accept _Sule...
# 46   ~Les _Illuminations_~ [Accept ~The _Illuminati...
# 283  _Jesus_ _Christ_ [accept either underlined par...
# 71               _Adunis_  [or Ali Ahmad Said _Esber_]
# 255                             Maxine Hong _Kingston_
# 170  Bruno _Latour_ \(The unnamed book is ~Science ...
# 137                                  _Xhosa_ (hoh-sah)
# 126  _Pre-Raphaelite Brotherhood_ [accept _PRB_ or ...
# 118                                     Antoni _Gaudí_
# 161                                   Louis _MacNeice_
# 105                                           _Aricia_
# 101                          Giles _Deleuze_ (De-luhz)
# 99      _Trade_ [prompt on __international exchange__]
# 98                                             _tree_s
# 166    _tris_ [or _tris\(hydroxymethyl\)aminomethane_]
# ..                                                 ...
# 260                                    Toni _Morrison_
# 120                                      Jean _Nouvel_
# 122   _Sengoku_ jidai [accept _Warring States_ Period]
# 228                                            _hukou_
# 208  _axial_ and _equatorial_ [accept in either order]
# 129                                 Carole _Pateman_
# 135  _Ignatius_ [or _Ignatius_ of Loyola, or _Ignaz...
# 273  _eight_ [accept _meson octet_ or _Eightfold_ Way]
# 104                                    Ronald _Reagan_
# 249                               _~Miles Gloriosus~_
# 253                                    _New Vrindaban_
# 47   _diabetes insipidus_ [or _DI_; do NOT accept o...
# 18                         _~Ars Nova~_ [or _New Art_]
# 169              _Harlequin_ [prompt on __guitarist__]
# 291                                        _Tuscarora_
# 287                                     _play-parties_
# 44                                       _Ito_'s Lemma
# 50                        _Liénard-Wiechert_ Potential
# 263                                _Phillips_ catalyst
# 298  _gambling_ or he _gambled_ [accept equivalents...
# 266                                  Tobias _Smollett_
# 202                              _American Revolution_
# 94                       _Hungary_ [or _Magyarország_]
# 83                                    "_The Sleepers_"
# 66                           _stork_  [accept _heron_]
# 93                                       Jane _Addams_
# 84                                    Joseph _Brodsky_
# 89                                          _analytic_
# 9    _Johann_ _Eck_ [accept either; accept _John_; ...
# 140                                      _Amir Khusro_
#
#                                   Category     Author  Edited  Packet  \
# 304                  Arts - Other Auditory     Hankin   False       0
# 0                          Science - Astro   Thompson    True       1
# 200                           History - US      Myers   False       1
# 201                         History - Euro      Myers   False       1
# 217                 Arts - Classical Music         Su   False       1
# 221                      Science - Physics     Bunker   False       1
# 226                        History - Other      Myers   False       1
# 165                    Science - Chemistry     Magin     True       1
# 229        Current Events - Current Events      Myers   False       1
# 241                  Geography - Geography      Myers   False       1
# 148                        Arts - Painting    Suttell   False       1
# 146                      Science - Biology     Magin     True       1
# 31                   Arts - Other Auditory         Su   False       1
# 41          Religion - Not Judeo-Christian     Bunker    True       1
# 131                Philosophy - Philosophy     Bunker    True       1
# 282                        History - World      Myers   False       1
# 46                       Literature - Euro     Bunker    True       1
# 283                   Literature - British     Hijazi    True       1
# 71            Literature - World / Ancient     Hijazi   False       1
# 255                  Literature - American    Suttell   False       1
# 170  Social Science - Psychology/Sociology     Bunker   False       1
# 137                        History - World      Myers   False       2
# 126                        Arts - Painting    Suttell   False       2
# 118                    Arts - Other Visual    Suttell   False       2
# 161                   Literature - British    Suttell   False       2
# 105                      Literature - Euro     Hijazi   False       2
# 101                Philosophy - Philosophy     Bunker    True       2
# 99              Social Science - Economics     Bunker   False       2
# 98            Literature - World / Ancient      Myers   False       2
# 166                    Science - Chemistry     Magin     True       2
# ..                                     ...        ...     ...     ...
# 260                  Literature - American    Suttell   False      15
# 120                    Arts - Other Visual    Suttell   False      15
# 122                        History - World      Myers   False      15
# 228        Current Events - Current Events      Myers   False      15
# 208                    Science - Chemistry     Bunker    True      15
# 129                Philosophy - Philosophy     Bunker    True      15
# 135             Religion - Judeo-Christian     Hijazi    True      15
# 273                      Science - Physics     Bunker   False      15
# 104                           History - US      Myers   False      15
# 249           Literature - World / Ancient     Hijazi   False      15
# 253         Religion - Not Judeo-Christian   Thompson    True      16
# 47                       Science - Biology     Bunker    True      16
# 18                  Arts - Classical Music     Hankin   False      16
# 169                        Arts - Painting    Suttell   False      16
# 291                           History - US      Myers   False      16
# 287                  Arts - Other Auditory      Myers   False      16
# 44         Other Academic - Other Academic     Bunker   False      16
# 50                       Science - Physics     Bunker   False      16
# 263                    Science - Chemistry  Mukherjee   False      16
# 298                            Myth - Myth     Bubolz    True      16
# 266                   Literature - British     Hijazi   False      16
# 202                        History - Other      Myers   False      16
# 94                 Philosophy - Philosophy     Bunker    True      16
# 83                   Literature - American     Hijazi   False      16
# 66            Literature - World / Ancient     Hijazi   False      16
# 93                  Social Science - Other     Bunker    True      16
# 84                       Literature - Euro     Hijazi   False      16
# 89                          Science - Math   Thompson    True      16
# 9                           History - Euro     Hankin   False      16
# 140                        History - World      Myers   False      16
#
#      Question Number                                           Comments     Id
# 304              0.0    Hbunker: This bonus will not be used for now.||  11593
# 0              999.0  Hbunker: Don't know much about astro, but how ...   9578
# 200            999.0                                                  0  11038
# 201            999.0  Hbunker: This bonus seems really easy if you h...  11040
# 217            999.0                                                  0  11064
# 221            999.0  incorvat: i think im bad but there are two ver...  11083
# 226            999.0                                                  0  11089
# 165            999.0  AaronK: Isn't it spelled VSEPR instead of VESP...  10982
# 229            999.0  CPiGuy: do you want to prompt or accept outrig...  11092
# 241            999.0                                                  0  11118
# 148            999.0                                                  0  10902
# 146            999.0  Hbunker: This bonus is too easy and short. Wha...  10900
# 31             999.0                                                  0   9690
# 41             999.0                                                  0   9781
# 131              0.0                                                  0  10816
# 282            999.0                                                  0  11409
# 46             999.0  Hbunker: Last part may change if someone has a...   9787
# 283            999.0  esuttell: Edited to mention exeter book on the...  11415
# 71             999.0  nour_hijazi: Let me know if this is too hard, ...  10132
# 255            999.0                                                  0  11164
# 170            999.0  Hbunker: considering changing hard part||ryan....  10991
# 137            999.0                                                  0  10867
# 126            999.0                                                  0  10794
# 118            999.0                                                  0  10781
# 161            999.0                                                  0  10961
# 105            999.0                                                  0  10682
# 101            999.0  Hbunker: consider changing the clues used for ...  10669
# 99             999.0               Hbunker: modified first part a bit||  10667
# 98             999.0  Hbunker: Bonus is supposedly too easy as writt...  10666
# 166            999.0  Hbunker: This is a good bonus. Maybe add a sen...  10983
# ..               ...                                                ...    ...
# 260            999.0                                                  0  11184
# 120            999.0                                                  0  10783
# 122            999.0                                                  0  10787
# 228            999.0                                                  0  11091
# 208            999.0  emukherj: M/E/H, I think, though its hard to t...  11052
# 129              0.0                                                  0  10814
# 135            999.0                                                  0  10841
# 273            999.0  Hbunker: Note: keep away from math group theor...  11209
# 104            999.0                                                  0  10677
# 249            999.0                                                  0  11149
# 253            999.0                           CPiGuy: Intended E/M/H||  11160
# 47             999.0  Hbunker: Last part is pretty bad and should be...   9789
# 18             999.0                                                  0   9607
# 169            999.0  Hbunker: Will Alston maybe says prompt on guit...  10989
# 291            999.0           Hbunker: Is this supposed to be M/E/H?||  11500
# 287            999.0                                                  0  11474
# 44             999.0                                                  0   9785
# 50             999.0  Hbunker: This bonus is too long and needs a re...   9794
# 263            999.0  Hbunker: consider changing the language in the...  11187
# 298            999.0  CPiGuy: changed "win" to "obtain" in the last ...  11553
# 266            999.0                                                  0  11197
# 202            999.0                                                  0  11041
# 94             999.0  Hbunker: Conor, when you live in Hungary, can ...  10610
# 83             999.0  jsmyers: A more difficulty-controlled middle p...  10466
# 66             999.0  Hbunker: How famous is this first thing Nour? ...  10062
# 93             999.0                                                  0  10604
# 84             999.0                                                  0  10467
# 89             999.0  Hbunker: The last part is impossibly long. The...  10499
# 9              999.0                                                  0   9596
# 140            999.0                                                  0  10884
#
# [322 rows x 14 columns]

# %%
print(b_df.shape)
b_df['Packet'].value_counts()
# Out:
# (322, 14)
# 13    21
# 16    20
# 7     20
# 1     20
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 8     20
# 15    20
# 9     20
# 10    20
# 11    20
# 12    20
# 14    20
# 0      1
# Name: Packet, dtype: int64

# %% [markdown]
# ## Classes

# %%
class Tossup():
    '''Tossup'''
    def __init__(self,q_text = 'No text', answer = 'No Answer', author = 'No Author', q_id = 9999, packet = 0):
        self.text = q_text
        self.answer = answer
        self.author = author
        self.q_id = q_id
        self.packet = packet
        self.category = None #important to fix
        
    def __repr__(self):
        '''Packet-like representation of a tossup'''
        return '{}\nANSWER: {} <{}>'.format(self.text, self.answer, self.author)
    
    def power(self):
        '''Returns an html formmated question text'''
        splits = self.text.split('(*)')
        power_str = "<b>" + splits[0] + '(*)</b>' + splits[1]
        self.text = power_str
        return self.text
    
    def bold_pg(self):
        '''adds pronounciation guides with bold formatting'''
        temp = self.text.replace('(', '(<b>')
        temp = temp.replace(')', '</b>)')
        temp = temp.replace('(<b>*','(*') #fixes for power marks
        temp = temp.replace('*</b>)','*)')
        self.text = temp
        return self.text
    
    def answer_bold_u(self):
        '''
        Returns answerline formatting including prompts
        '''
        regex_answer = r'(?<=\_)(.*)(?=\_)'
        pattern_answer = r'<b><u>\1</u></b>'
        regex_prompt = r'(?<=\__)(.*)(?=\__)'
        pattern_prompt = r'<u>\1</u>'
        tokens = self.answer.split()

        temp_list = [re.sub(regex_prompt, pattern_prompt,t) for t in tokens]
        no_prompts = " ".join(temp_list).replace('__','') #double 'prompt' underscore
        tokens = no_prompts.split() #remake new tokens for no prompts list

        cleaned_list = [re.sub(regex_answer, pattern_answer, t) for t in tokens] #each word in the answerline
        self.answer = " ".join(cleaned_list).replace('_','')
        return self.answer
    
    def clean_html(self):
        def italicize(mytext):
            '''returns italicized text'''
            regex = r'(?<=\~)(.*)(?=\~)'
            pattern = r"<i>\1</i>"
            splits = mytext.split('.') #split on period
            temp_list = [re.sub(regex, pattern, sent) for sent in splits]
            return '.'.join(temp_list).replace('~','')
        
        #Question TEXT
        powered = self.power()
        pg = self.bold_pg()
        italicized = italicize(pg)
        self.text = italicized
        
        #ANSWER
        self.answer = self.answer_bold_u()
        self.answer = italicize(self.answer)
        #add #<br>tag for new line in printing
        return self
    
class Bonus():
    '''Bonus'''
    def __init__(self, lead_in = 'Blank', q_list = ['No text','No text', 'No text'], answer_list = ['No Answer', 'No Answer', 'No Answer'],
                author = 'No Author', q_id = 9999, packet = 0):
        self.lead_in = lead_in
        self.q_list = q_list
        self.answer_list = answer_list
        self.author = author
        self.q_id = q_id
        self.packet = packet
        self.category = None #important to fix
    
    def __repr__(self):
        print_str = '{}\n[10]{}\nANSWER: {}\n[10]{}\nANSWER:{}\n[10]{}\nANSWER:{} <{}>'.format(self.lead_in, 
                                                                 self.q_list[0], self.answer_list[0],
                                                                 self.q_list[1], self.answer_list[1],
                                                                 self.q_list[2], self.answer_list[2], self.author)
        return print_str
    
    def answer_bold_u(self):
        '''
        Returns answerline formatting including prompts
        '''
        regex_answer = r'(?<=\_)(.*)(?=\_)'
        pattern_answer = r'<b><u>\1</u></b>'
        regex_prompt = r'(?<=\__)(.*)(?=\__)'
        pattern_prompt = r'<u>\1</u>'
        temp_list = []
        
        for answer in self.answer_list:
            tokens_answer = answer.split()
            no_prompts_list = [re.sub(regex_prompt, pattern_prompt,t) for t in tokens_answer]
            no_prompts = " ".join(no_prompts_list).replace('__','') #double 'prompt' underscore
            #print('no prompts',no_prompts)
            tokens = no_prompts.split() #remake new tokens for no prompts list

            cleaned_list = [re.sub(regex_answer, pattern_answer, t) for t in tokens] #each word in the answerline
            temp = " ".join(cleaned_list).replace('_','')
            temp_list.append(temp)
        self.answer_list = temp_list #reassign answers to have prompt and answerline formatting
        return self
    
    def bold_pg(self):
        '''adds pronounciation guides with bold formatting'''
        #lead-in
        temp = self.lead_in.replace('(', '(<b>')
        temp = temp.replace(')', '</b>)')
        self.lead_in = temp
        #rest of bonus:
        temp_list = []
        for text in self.q_list:
            temp = text.replace('(', '(<b>')
            temp = temp.replace(')', '</b>)')
            temp_list.append(temp)
        self.q_list = temp_list    
        return self
    
    def clean_html(self):
        '''returns text optimized for html'''
        def italicize(mytext):
            '''returns italicized text'''
            regex = r'(?<=\~)(.*)(?=\~)'
            pattern = r"<i>\1</i>"
            splits = mytext.split('.') #split on period
            temp_list = [re.sub(regex, pattern, sent) for sent in splits]
            return '.'.join(temp_list).replace('~','')
        #QUESTIONS
        self.bold_pg()
        self.lead_in = italicize(self.lead_in) #italics
        temp_list = []
        for q in self.q_list:
            temp = italicize(q)
            temp_list.append(temp)
        self.q_list = temp_list
        #ANSWERS
        self.answer_bold_u()
        temp_list2 = []
        for answer in self.answer_list:
            temp = italicize(answer)
            temp.replace('/(','(') #fix parens
            temp_list2.append(temp)
        self.answer_list = temp_list2    
        return self

# %%
class Packet(): #possibly add a way to load in the preamble from a markup file of .txt
    '''Packet with comes with its template and a list of its tossups, bonuses'''
    
    def __init__(self, tu_list, b_list, p_num = 0, 
                 template_tu = np.zeros((20,2), dtype = str), template_b = np.zeros((20,2), dtype = str),
                 size = 20, preamble = ''):
        '''tu_list is made up of Tossup objects, b_list is made up of Bonus objects
        size only works for 20 for now
        preamble is printed at the front of each packet'''
        
        self.number = p_num
        self.template_tu = template_tu #need to make for tossups and bonuses
        self.template_b = template_b
        self.tu_list = tu_list
        self.b_list = b_list
        self.max_size = size #number of tossups or bonuses (e.g. for 20/20 -> 20)   
        #self.ordered = [[],[]] #ordered list of tossups and bonus
        self.preamble = preamble #printed before Tossup 1 for each packet
        
    def __len__(self):
        '''Prints many questions in packets'''
        return len(self.tu_list) + len(self.b_list)
    
    def __repr__(self):
        return 'Packet {} consisting of {} Tossups and {} Bonuses'.format(self.number, len(self.tu_list), 
                                                                          len(self.b_list))
    def __getitem__(self, param): #need to fix
        '''Input: param1 is in {'tossup', 'bonus'} and param2 is a number in {1, ..., max_size}
        Returns: a tossup or bonus
        '''
        #error handling
        if len(param) != 2:
            raise ValueError('Must be a pair of format ("tossup",num) or ("tossup",num)')
        if param[0].lower() not in ["tossup", 'bonus']:
            raise ValueError('First argument must be either "tossup" or "bonus"')
        if param[0].lower() == 'tossup':
            #print('tossup')
            return self.tu_list[param[1] - 1] #support of 1-indexing
        if param[0].lower() == 'bonus':
            #print('bonus')
            return self.b_list[param[1] - 1] #support of 1-indexing
            
        else: #outside the values that currently exist
            raise ValueError('{} is not a valid index'.format(param[1]))
        
    def add(self, item, clean = False):
        #cleaning for HTML formatting
        '''Add tossups and bonuses to a packet'''
        if isinstance(item, Tossup) == True:
                #print('tossup')
            if len(self.tu_list) != self.max_size:
                self.tu_list.append(item)
            else:
                print('Packet {} full of tossups'.format(self.number))
                return self
        elif isinstance(item, Bonus) == True:
            #print('bonus')
            if len(self.b_list) != self.max_size:
                self.b_list.append(item)
            else:
                print('Packet {} full of bonuses'.format(self.number))
                return self
        else:
            raise TypeError("Can't add object of {} type".format(type(item)))
        return self
    
    def to_txt(self):
        fname = './Packet' + str(self.number) + '.txt'
        wp = open(fname, 'w')
        wp.write(self.preamble)
        #wp.write('') #blank line
        wp.write('\nPacket ' + str(self.number) + '\n\n')
        #Tossups
        wp.write('\nTossups:\n\n')
        count = 0
        for t in self.tu_list:
            count += 1 
            wp.write(str(count) + '. ' + str(t))
            wp.write('\n\n')
        #Bonuses    
        wp.write('Bonuses:\n\n')
        count = 0
        for b in self.b_list:
            count += 1
            wp.write(str(count) + '. ' + str(b))
            wp.write('\n\n')
        wp.close()
        return 'file saved at {}'.format(fname)
    
    def to_html(self):
        #lead-in
        fname = './Packet' + str(self.number) + '.html'
        wp = open(fname,'w')
        wp.write('<html>\n<head>\n<title>' + 'Packet' + str(self.number) + '</title>\n') #title
        wp.write('<br><p><font size="6">' + 'Packet' + str(self.number) + '</font></p>')
        wp.write('<body>')
        wp.write('<p>' + self.preamble + '</p>')
        wp.write('<br><p>Tossups:</p><br>')
        count = 0
        for t in self.tu_list:
            count += 1
            wp.write('<p>' + str(count) + '. ' + str(t).replace('\n','<br>') + '</p>')
            #wp.write('<br>')
        count = 0
        wp.write('<br><p>Bonues:</p><br>')
        for b in self.b_list:
            count += 1
            wp.write('<p>' + str(count) + '. ' + str(b).replace('\n','<br>') + '</p>')
            #wp.write('<br>')
        wp.write("</body>\n</html>")                            
        wp.close()
        return 'file saved at' + fname
    
    def randomize(self, random = True):
        if random == True:
            #uses np.random.shuffle() on tossup and bonus lists
            np.random.seed(328)
            np.random.shuffle(self.tu_list)
            np.random.shuffle(self.b_list)
        if random == False:
            #use a pre-built template #need to build-out
            if self.template_tu.size != (self.max_size,2):
                raise ValueError('Template is not of correct size or is empty.\n It should be of (max_length, 2) size (e.g. 20 x 2)')
            else:
                pass #need to build out
        
        print('randomized')
        return self

# %%
blank = Packet([],[])
len(blank)
# Out:
# 0

# %% [markdown]
# ## Add Tossups

# %%
Packet1 = Packet(p_num =1, tu_list = [], b_list = [], preamble = 'This is SHW by this guy and this guy')
Packet2 = Packet(p_num = 2, tu_list = [], b_list = [])
print('tostart:', Packet1)

for index, row in t_df.iterrows():
    text = row['Tossup Question']
    answer = row['Answer']
    author = row['Author']
    packet = row['Packet']
    t_id = row['Id']
    temp_tu = Tossup(text, answer, author, t_id, packet)
    category = row['Category']
    for index2, row2 in distro_df.iterrows():
        if category in row2['Tags']:
            #print("in",category)
            temp_tu.category = row2['Subcategory']
    if temp_tu.packet == 1:
        #print('1')
        Packet1.add(temp_tu.clean_html())
    if temp_tu.packet == 2:
        #print('2')
        Packet2.add(temp_tu)
    
print(Packet1)
# Out:
# tostart: Packet 1 consisting of 0 Tossups and 0 Bonuses
# Packet 1 consisting of 20 Tossups and 0 Bonuses

# %% [markdown]
# ## Add Bonuses

# %%
for index, row in b_df.iterrows():
    lead_in = row['Bonus Leadin']
    q_list = [row['Bonus Part 1'], row['Bonus Part 2'], row['Bonus Part 3']]
    answer_list = [row['Bonus Answer 1'] , row['Bonus Answer 2'], row['Bonus Answer 3']]
    author = row['Author']
    b_id = row['Id']
    packet = row['Packet']
    temp_b = Bonus(lead_in, q_list, answer_list, author, b_id, packet)
    category = row['Category']
    for index2, row2 in distro_df.iterrows():
        if category in row2['Tags']:
            #print("in",category)
            temp_b.category = row2['Subcategory']
    if temp_b.packet == 1:
        Packet1.add(temp_b.clean_html())
print(Packet1)
# Out:
# Packet 1 consisting of 20 Tossups and 20 Bonuses

# %% [markdown]
# ## Export

# %%
Packet1.to_txt()
# Out:
# 'file saved at ./Packet1.txt'

# %%
Packet1.randomize()
Packet1.to_html()
# Out:
# randomized
# 'file saved at./Packet1.html'

# %% [markdown]
# ## Testing

# %%
Packet1['tossup',1]
# Out:
# tossup
# <b>In one story written in this language, a sheep with no wool flees into the plain after having a conversation with some horses and lamenting that they are driven by men. A revised version of that text by Hermann Hirt included labialized and palatized velars, and later Douglas Q. Adams published a version of that story which incorporated the laryngeal theory of this language's phonology. That text in this language was first composed by linguist August (*)</b> Schleicher. Another story in this language was composed by Eric P. Hamp in an attempt to reconstruct the "ancestor" to a short passage from ancient Indian scriptures. Despite the fact that this language's speakers, whose homeland is the subject of the Kurgan hypothesis, did not have a writing system, linguists have reconstructed it through the use of the comparative method. For 10 points, identify this language spoken between 3,000 and 6,000 years ago whose daughter languages are now spoken across Europe and India.
# ANSWER: <b><u>Proto-Indo-European</u></b> [or <b><u>PIE</u></b>, do not accept "Indo-European", because that is not a language] <Thompson>

# %%
Packet1.randomize(False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-150-9e52a9ed8a4a> in <module>
# ----> 1 Packet1.randomize(False)
#
# <ipython-input-147-776857d7f174> in randomize(self, random)
#     116             #use a pre-built template #need to build-out
#     117             if self.template.size != (self.max_size,2):
# --> 118                 raise ValueError('Template is not of correct size or is empty.\n It should be of (max_length, 2) size (e.g. 20 x 2)')
#     119
#     120
#
# ValueError: Template is not of correct size or is empty.
#  It should be of (max_length, 2) size (e.g. 20 x 2)

# %%
a = np.zeros((20,2), dtype=Tossup, Bonus)
a[:,0] = Packet1.tu_list
a
# Out:
#   File "<ipython-input-162-3aaf8f857ecf>", line 1
#     a = np.zeros((20,2), dtype=Tossup, Bonus)
#                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
np.random.seed(1)
mylist = list(range(100))
np.random.shuffle(mylist)
mylist
# Out:
# [80,
#  84,
#  33,
#  81,
#  93,
#  17,
#  36,
#  82,
#  69,
#  65,
#  92,
#  39,
#  56,
#  52,
#  51,
#  32,
#  31,
#  44,
#  78,
#  10,
#  2,
#  73,
#  97,
#  62,
#  19,
#  35,
#  94,
#  27,
#  46,
#  38,
#  67,
#  99,
#  54,
#  95,
#  88,
#  40,
#  48,
#  59,
#  23,
#  34,
#  86,
#  53,
#  77,
#  15,
#  83,
#  41,
#  45,
#  91,
#  26,
#  98,
#  43,
#  55,
#  24,
#  4,
#  58,
#  49,
#  21,
#  87,
#  3,
#  74,
#  30,
#  66,
#  70,
#  42,
#  47,
#  89,
#  8,
#  60,
#  0,
#  90,
#  57,
#  22,
#  61,
#  63,
#  7,
#  96,
#  13,
#  68,
#  85,
#  14,
#  29,
#  28,
#  11,
#  18,
#  20,
#  50,
#  25,
#  6,
#  71,
#  76,
#  1,
#  16,
#  64,
#  79,
#  5,
#  75,
#  9,
#  72,
#  12,
#  37]
